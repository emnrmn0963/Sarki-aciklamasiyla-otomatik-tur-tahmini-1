# %%
import pandas as pd
import os
import numpy as np
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
import re

# %%
df = pd.read_csv("C:/Users/yunus/Desktop/emine_proje/data/top500song.csv")

# %%
df.head()
# Out:
#                             title  \
# 0            Like a Rolling Stone
# 1  (I Can't Get No) Satisfaction'
# 2                         Imagine
# 3                 What's Going On
# 4                         Respect
#
#                                          description  \
# 0  "I wrote it. I didn't fail. It was straight,"�...
# 1  "It's the riff heard round the world," says St...
# 2  John Lennon wrote "Imagine," his greatest musi...
# 3  "What's Going On" is an exquisite plea for pea...
# 4  Otis Redding wrote "Respect" and recorded it f...
#
#                                           appears on              artist  \
# 0                    Highway 61 Revisited (Columbia)           Bob Dylan
# 1                           Out of Our Heads�(ABKCO)  The Rolling Stones
# 2                            Imagine�(Capitol/Apple)         John Lennon
# 3                            What's Going On�(Tamla)         Marvin Gaye
# ...

# %%
def preprocess_text(text):
    sentences = nltk.sent_tokenize(text)
    processed_sentences = []
    for sentence in sentences:
        # 2. Küçük harfe çevirme
        sentence = sentence.lower()
        
        # 3. Noktalama işaretlerini kaldırma
        sentence = re.sub(r'[^\w\s]', '', sentence)
        
        # 4. Tokenizasyon
        tokens = nltk.word_tokenize(sentence)
        
        # 5. Stop word temizliği
        stop_words = set(stopwords.words('turkish'))
        tokens = [token for token in tokens if token not in stop_words]
        
        # 6. Lemmatizasyon
        lemmatizer = WordNetLemmatizer()
        tokens = [lemmatizer.lemmatize(token) for token in tokens]
        
        processed_sentences.append(tokens)
    
    return processed_sentences

# %%
# Fonksiyonu kullanarak işlemleri uygulama
df['description_processed'] = df['description'].apply(preprocess_text)

# %%
print(df['description_processed'].head())
# Out:
# 0    [[i, wrote, it], [i, didnt, fail], [it, wa, st...
# 1    [[it, the, riff, heard, round, the, world, say...
# 2    [[john, lennon, wrote, imagine, his, greatest,...
# 3    [[whats, going, on, is, an, exquisite, plea, f...
# 4    [[otis, redding, wrote, respect, and, recorded...
# Name: description_processed, dtype: object

# %%
df.to_csv("C:/Users/yunus/Desktop/emine_proje/data/preprocessed_data_lemmatized_only.csv", index=False)

# %%
veri = pd.read_csv("C:/Users/yunus/Desktop/emine_proje/data/preprocessed_data_lemmatized_only.csv")
veri.head(10)
# Out:
#                             title  \
# 0            Like a Rolling Stone
# 1  (I Can't Get No) Satisfaction'
# 2                         Imagine
# 3                 What's Going On
# 4                         Respect
# 5                 Good Vibrations
# 6                 Johnny B. Goode
# 7                        Hey Jude
# 8         Smells Like Teen Spirit
# 9                    What'd I Say
#
#                                          description  \
# 0  "I wrote it. I didn't fail. It was straight,"�...
# 1  "It's the riff heard round the world," says St...
# 2  John Lennon wrote "Imagine," his greatest musi...
# 3  "What's Going On" is an exquisite plea for pea...
# 4  Otis Redding wrote "Respect" and recorded it f...
# 5  "It scared me, the word 'vi-brations,'"�Brian ...
# 6  "Johnny B. Goode" was the first rock & roll hi...
# 7  The Beatles' biggest U.S. single � nine weeks ...
# 8  Producer Butch Vig first heard "Smells Like Te...
# ...

# %%
df2 = pd.read_csv("C:/Users/yunus/Desktop/emine_proje/data/top500song.csv")

# %%
def stem_text(text):
  #Cümlelere ayırma
    sentences = nltk.sent_tokenize(text)
    
    processed_sentences = []
    for sentence in sentences:
        #Küçük harfe çevirme
        sentence = sentence.lower()
        #Noktalama işaretlerini kaldırma
        sentence = re.sub(r'[^\w\s]', '', sentence)
        #Tokenizasyon
        tokens = nltk.word_tokenize(sentence)
        #Stop word temizleme
        stop_words = set(stopwords.words('english'))
        tokens = [token for token in tokens if token not in stop_words]
        #Stemming
        stemmer = PorterStemmer()
        tokens = [stemmer.stem(token) for token in tokens]
        processed_sentences.append(tokens)
    return processed_sentences

# %%
df2['description_stemmed'] = df2['description'].apply(stem_text)

# %%
df2.to_csv("C:/Users/yunus/Desktop/emine_proje/data/preprocessed_data_stemmed_only.csv", index=False)

# %%
veri2 = pd.read_csv("C:/Users/yunus/Desktop/emine_proje/data/preprocessed_data_stemmed_only.csv")
veri.head(10)
# Out:
#                             title  \
# 0            Like a Rolling Stone
# 1  (I Can't Get No) Satisfaction'
# 2                         Imagine
# 3                 What's Going On
# 4                         Respect
# 5                 Good Vibrations
# 6                 Johnny B. Goode
# 7                        Hey Jude
# 8         Smells Like Teen Spirit
# 9                    What'd I Say
#
#                                          description  \
# 0  "I wrote it. I didn't fail. It was straight,"�...
# 1  "It's the riff heard round the world," says St...
# 2  John Lennon wrote "Imagine," his greatest musi...
# 3  "What's Going On" is an exquisite plea for pea...
# 4  Otis Redding wrote "Respect" and recorded it f...
# 5  "It scared me, the word 'vi-brations,'"�Brian ...
# 6  "Johnny B. Goode" was the first rock & roll hi...
# 7  The Beatles' biggest U.S. single � nine weeks ...
# 8  Producer Butch Vig first heard "Smells Like Te...
# ...
